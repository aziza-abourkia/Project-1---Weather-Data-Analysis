# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\AB Khadija\Desktop\My Projects\weatherHistory.csv')

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# ## Let's take a look of the total no. of rows and no. of columns of the dataframe .

# %%
data.shape
# Out:
# (96453, 12)

# %% [markdown]
# ## Show the datatype of each column

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %% [markdown]
# ## Show the name of each column

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# ## Let's show all the unique values in the 'Summary' column

# %%
data['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %% [markdown]
# ## Show all the unique values with their count in the 'Summary' column

# %%
data['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %% [markdown]
# ## Find all the unique"Wind Speed" values in the data.

# %%
data.head(3)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# ...

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# ## Find the number of times when the weather is Foggy with three different methods

# %%
# value_counts()
data.Summary.value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
#filtering
data[data.Summary == "Foggy"]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain        10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain         8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain         8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain         8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain         5.211111
# ...                              ...     ...         ...              ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain        13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain        13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain        13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain        14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain        22.800000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
#groupby()
data.groupby('Summary').get_group('Foggy')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain        10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain         8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain         8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain         8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain         5.211111
# ...                              ...     ...         ...              ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain        13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain        13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain        13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain        14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain        22.800000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# ## Find the number of times when the 'Wind Bearing was exactly 210 degrees'

# %%
data[data['Wind Bearing (degrees)'] == 210]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 391    2006-04-24 07:00:00.000 +0200          Clear        rain
# 625    2006-04-06 01:00:00.000 +0200       Overcast        rain
# 683    2006-04-08 11:00:00.000 +0200  Partly Cloudy        rain
# 737    2006-08-01 17:00:00.000 +0200  Mostly Cloudy        rain
# 847    2006-08-14 07:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 95707  2016-10-08 22:00:00.000 +0200  Mostly Cloudy        rain
# 95912  2016-09-16 11:00:00.000 +0200          Clear        rain
# 95919  2016-09-16 18:00:00.000 +0200  Mostly Cloudy        rain
# 96120  2016-09-24 03:00:00.000 +0200          Clear        rain
# 96328  2016-09-04 19:00:00.000 +0200       Overcast        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 391          10.911111                 10.911111      0.99             1.6100
# ...

# %% [markdown]
# ## Rename the column name 'Summary' of the dataframe to 'Weather'

# %%
data.rename(columns = {'Summary' : 'Weather'} , inplace=True ) #we add inplace=True to make it permanent

# %%
data.head(3) #Here below we can see that the change has been made
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# ...

# %% [markdown]
# ## The mean of 'Humidity'

# %%
data.Humidity.mean()
# Out:
# 0.7348989663358906

# %% [markdown]
# ## The Standard Deviation of 'Pressure' in this data

# %%
data['Pressure (millibars)'].std()  # We use the '[]' instead of the '.' when there is a space in the name of column
# Out:
# 116.96990568258147

# %% [markdown]
# ## The Variance of 'Humidity' in this data

# %%
data.Humidity.var()
# Out:
# 0.03820959171844407

# %% [markdown]
# ## All instances when 'Visibility is above 10' and ' Humidity  is 0.81'

# %%
data[(data['Visibility (km)'] > 10)  & (data['Humidity'] == 0.81)]
# Out:
#                       Formatted Date        Weather Precip Type  \
# 64     2006-04-11 16:00:00.000 +0200  Mostly Cloudy        rain
# 143    2006-04-14 23:00:00.000 +0200  Mostly Cloudy        rain
# 589    2006-04-04 13:00:00.000 +0200       Overcast        rain
# 674    2006-04-08 02:00:00.000 +0200          Clear        rain
# 722    2006-08-01 02:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96285  2016-09-30 00:00:00.000 +0200  Partly Cloudy        rain
# 96307  2016-09-30 22:00:00.000 +0200          Clear        rain
# 96336  2016-09-05 03:00:00.000 +0200  Mostly Cloudy        rain
# 96337  2016-09-05 04:00:00.000 +0200  Mostly Cloudy        rain
# 96429  2016-09-09 00:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 64           15.633333                 15.633333      0.81            23.6992
# ...

# %% [markdown]
# ## The Mean value of each column against each 'Weather'

# %%
data.groupby('Weather').mean()
# Out:
#                                      Temperature (C)  \
# Weather
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.925109
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.464035
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %% [markdown]
# ## All instances when 'Weather '  is Windy  or 'Visibility' is above 10

# %%
data[(data['Weather'] == 'Windy')  |  (data['Visibility (km)'] > 10)]
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# ## All instances when : A.'Weather is clear'and 'Humidity is greater than 0.5' or B.'Visibility is above 16'

# %%
data[(data['Weather'] == 'Clear')  & (data['Humidity'] > 0.5) | (data['Visibility (km)'] > 16)]
# Out:
#                       Formatted Date        Weather Precip Type  \
# 223    2006-04-18 07:00:00.000 +0200          Clear        rain
# 309    2006-04-20 21:00:00.000 +0200          Clear        rain
# 337    2006-04-22 01:00:00.000 +0200          Clear        rain
# 338    2006-04-22 02:00:00.000 +0200          Clear        rain
# 357    2006-04-22 21:00:00.000 +0200          Clear        rain
# ...                              ...            ...         ...
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 223           8.688889                  8.688889      0.93             1.4329
# ...
